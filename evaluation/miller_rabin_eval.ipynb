# %%
import matplotlib.pyplot as plt

k = [1,2,3,4,5,10,15,30,45]
accuracy = [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
runtimes = [1.5025632455945015e-06, 1.772537361830473e-06, 2.6824732776731253e-06, 3.3124955371022223e-06, 4.063333617523312e-06, 8.044135756790639e-06, 1.2241721851751208e-05, 2.3591602221131326e-05, 3.650250262580812e-05]

fig, ax1 = plt.subplots()
ax1.set_title('Miller-Rabin for prime numbers')
ax1.set_xlabel('k')

ax1.plot(k, runtimes, 'purple')
ax1.set_ylabel('Average runtime (s)', color = 'purple')

ax2 = ax1.twinx()
ax2.plot(k, accuracy)
plt.ylim(0,110)
ax2.set_ylabel('Accuracy (%)', color = 'tab:blue')
plt.show()

# %%
import matplotlib.pyplot as plt

k = [1,2,3,4,5,10,15,30,45]
accuracy = [97.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]
runtimes = [1.2367102317512036e-06, 1.2446072651073336e-06, 1.3066409155726432e-06, 1.2570898979902267e-06, 1.263357698917389e-06, 1.2609089026227593e-06, 1.3112666783854365e-06, 1.2842169962823391e-06, 1.4750630361959338e-06]

fig, ax1 = plt.subplots()
ax1.set_title('Miller-Rabin for composite numbers')
ax1.set_xlabel('k')

ax1.plot(k, runtimes, 'purple')
ax1.set_ylabel('Average runtime (s)', color = 'purple')

ax2 = ax1.twinx()
ax2.plot(k, accuracy)
ax2.set_ylabel('Accuracy (%)', color = "tab:blue")
plt.show()
