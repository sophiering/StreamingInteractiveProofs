# %%
import matplotlib.pyplot as plt
import math

n = [int(math.pow(2,10)), int(math.pow(2,15)), int(math.pow(2,20))]
accuracy_t = [100.0, 100.0, 100.0]
runtimes_t = [2.654713249668324, 4.615817226889906, 4.155901259341691]
accuracy_f = [100.0, 100.0, 100.0]
runtimes_f = [3.36647811590875, 2.9827223427710123, 4.0056130139920345]

fig, ax1 = plt.subplots()
ax1.set_title('Equality')
ax1.set_xlabel('n')

ax1.plot(n, runtimes_t, 'purple')
ax1.plot(next, runtimes_f, 'purple')
ax1.set_ylabel('Average runtime (s)', color = 'purple')

ax2 = ax1.twinx()
ax2.plot(n, accuracy_t)
ax2.plot(n, accuracy_f)
plt.ylim(0,110)
ax2.set_ylabel('Accuracy (%)', color = 'tab:blue')
plt.show()



plt.plot(size, time)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 15
#      12 ax1.set_xlabel('n')
#      14 ax1.plot(n, runtimes_t, 'purple')
# ---> 15 ax1.plot(next, runtimes_f, 'purple')
#      16 ax1.set_ylabel('Average runtime (s)', color = 'purple')
#      18 ax2 = ax1.twinx()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# ...
